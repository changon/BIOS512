# %%
library('tidyverse')
library('rvest')
library('lubridate')
options(repr.plot.res = 300, repr.plot.width = 6, repr.plot.height = 6)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Loading required package: xml2
#
#
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:purrr’:
#
#     pluck
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following object is masked from ‘package:base’:
#
#     date

# %%
scrape_table = function(i, MF='Women\'s') {
    url = "https://www.baa.org/races/boston-marathon/results/champions"
    webpage = xml2::read_html(url)
    tbl = html_nodes(webpage, "table")[[i]] %>%
        html_table() %>%
        drop_na() %>%
        magrittr::set_colnames(c('year', 'name', 'country', 'time')) %>%
        mutate(time = hms(time)) %>%
        mutate(race.time = as.numeric(time, 'hours')) %>%
        mutate(MF = MF) %>%
        mutate(
            country.simple = ifelse(
                country %in% c('United States', 'Ethiopia', 'Japan', 'Kenya'),
                country,
                'other'
            )
        )
    tbl
}

df.men = scrape_table(1, MF='Men\'s')
df.women = scrape_table(2)

df.marathon = rbind(df.men, df.women)

# %%
df.marathon %>% head
# Out:
#   year name                       country       time       race.time MF
# 1 2019 Lawrence Cherono           Kenya         2H 7M 57S  2.132500  Men's
# 2 2018 Yuki Kawauchi              Japan         2H 15M 58S 2.266111  Men's
# 3 2017 Geoffrey Kirui             Kenya         2H 9M 37S  2.160278  Men's
# 4 2016 Lemi Berhanu               Ethiopia      2H 12M 45S 2.212500  Men's
# 5 2015 Lelisa Desisa              Ethiopia      2H 9M 17S  2.154722  Men's
# 6 2014 Mebrahtom "Meb" Keflezighi United States 2H 8M 37S  2.143611  Men's
#   country.simple
# 1 Kenya
# 2 Japan
# 3 Kenya
# 4 Ethiopia
# 5 Ethiopia
# 6 United States

# %% [markdown]
# Let's re-create this chart from FiveThirtyEight

# %% [markdown]
# <center>
#     <img src="https://fivethirtyeight.com/wp-content/uploads/2018/04/wezerek-marathon-0416-13.png"
#          style="width: 600px;"/>
# </center>

# %%
df.label = df.marathon %>% 
    filter(country.simple %in% c('United States', 'Japan', 'Kenya', 'Ethiopia')) %>%
    group_by(MF, country.simple) %>%
    summarize(median.year = median(year), median.time = median(race.time))

df.label
# Out:
#   MF      country.simple median.year median.time
# 1 Men's   Ethiopia       2011.0      2.163750
# 2 Men's   Japan          1966.0      2.275833
# 3 Men's   Kenya          2001.0      2.155139
# 4 Men's   United States  1927.5      2.478889
# 5 Women's Ethiopia       2009.0      2.407778
# 6 Women's Kenya          2007.5      2.411389
# 7 Women's United States  1977.5      2.766944

# %%
library('ggrepel')

# %%
p = ggplot(df.marathon, aes(x = year, y = race.time, color = country.simple))

p = p + geom_point()

p = p + facet_wrap(~ MF, ncol = 1, scales = 'free_x')

p = p + theme(legend.position = 'none')

p = p + geom_text_repel(data = df.label, aes(x = median.year, y = median.time, label=country.simple), 
                        segment.size=.1,segment.color='grey20', size = 6, nudge_y=.35)

p=p+scale_color_manual(values=c('#8dd3c7','#ffffb3', '#bebeda','#fbbbbb', '#151515'))

p=p+theme_bw()

p=p+theme(legend.position='none') #, strip.border=element_blank())

p=p+labs(y='Winning time', x='Year')

p
# Out:
# plot without title

# %%
p = ggplot(df.marathon, aes(x = country))

p = p + geom_bar()

p = p + coord_flip()

p
# Out:
# plot without title

# %% [markdown]
# Preview the data (i.e. `df.marathon`).

# %%
head(df.marathon)

# %% [markdown]
# Fill in the table below:

# %% [markdown]
# | chart property | column name |
# | --- | --- |
# | x value | year |
# | y value | ? |
# | color | ? |
# | facet value | ? |

# %% [markdown]
# Make note of other aesthetic decisions.
# - What's the y-axis title?
# - Do the two charts share the same x-axis bounds?
# - Is there a legend?

# %% [markdown]
# Code your version of the chart below.

# %%
# see above and past notes

# %% [markdown]
# What else might you visualize with this data? (e.g. What about totaling the winners from each country?)

# %%
# bar chart as in past notes
