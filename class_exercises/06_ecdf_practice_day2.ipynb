# %% [markdown]
# # ECDF plots

# %%
# uncomment the following:

library('tidyverse')
options(repr.plot.res = 300)  # This is useful to get sensible default sizing

otter.data = read.csv('https://jcoliver.github.io/learn-r/data/otter-mandible-data.csv') %>%
     gather(characteristic, value, -species, -museum, -accession) %>%
     drop_na()
otter.data %>% head
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.2.0     ✔ purrr   0.3.2
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   0.8.3     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#   species    museum accession characteristic value
# 1 A. cinerea AMNH   101458    m1             15.100
# 2 A. cinerea AMNH   101461    m1             12.740
# 3 A. cinerea AMNH   101466    m1             12.425
# 4 A. cinerea AMNH   101635    m1             13.400
# 5 A. cinerea AMNH   101459    m1             14.400
# 6 A. cinerea AMNH   101462    m1             14.525

# %% [markdown]
# Make an ECDF plot of `value` and:
# - facet by characteristic
# - allow the x-axis of each facetted plot to be independent (hint use the `scales` argument)
# - color/group by species
#
# Species names are typically italicized. Use `theme` and `element_text` to adjust the legend text so that it is italic.
#
# Which otter species has the smallest skull?

# %%
options(repr.plot.res=300, repr.plot.height=7, repr.plot.width=10)
p=ggplot(otter.data, aes(x=value, color=species))
p=p+facet_wrap(~characteristic, scales="free_x") #or "free_y" for just y
p=p+stat_ecdf(geom="point", size=.05, alpha=.5)

p=p+theme(legend.text=element_text(face='italic')
            , axis.text.x=element_text(color='red'), legend.position='bottom'
         )

p=p+ggtitle('ECDF of Value facetted by Characteristic')

p
# Out:
# plot without title

# %% [markdown]
# A. cinerea have the smallest skulls (as shown by red points being lower on the x axis)

# %%
otter.data$species = factor(otter.data$species , 
                            levels=c("A. cinerea","L. canadensis","E. lutris","P. brasiliensis"))

# %%
library(forcats) # to use reorder, for organizing the factor levels, that we did manually above. 
# can also graph the otter.data$species.new below

# %%
otter.data %>%  
    mutate(species.new = fct_reorder(species, value)) # create new cols
# Out:
#     species         museum      accession characteristic value
# 1   A. cinerea      AMNH        101458    m1             15.100
# 2   A. cinerea      AMNH        101461    m1             12.740
# 3   A. cinerea      AMNH        101466    m1             12.425
# 4   A. cinerea      AMNH        101635    m1             13.400
# 5   A. cinerea      AMNH        101459    m1             14.400
# 6   A. cinerea      AMNH        101462    m1             14.525
# 7   A. cinerea      AMNH        101467    m1             13.665
# 8   A. cinerea      AMNH        101471    m1             13.175
# 9   A. cinerea      AMNH        101636    m1             12.505
# 10  A. cinerea      AMNH        101460    m1             13.230
# 11  A. cinerea      AMNH        101465    m1             15.615
# 12  A. cinerea      AMNH        101468    m1             11.140
# 13  A. cinerea      AMNH        101634    m1             13.055
# 14  A. cinerea      AMNH        101639    m1             12.080
# 15  A. cinerea      AMNH        101464    m1             13.410
# 16  A. cinerea      AMNH        101469    m1             13.515
# 17  A. cinerea      AMNH        101470    m1             13.470
# 18  A. cinerea      AMNH        101637    m1             13.390
# 19  A. cinerea      AMNH        101638    m1             13.930
# 20  A. cinerea      Smithsonian 396645    m1             12.150
# 21  A. cinerea      Smithsonian 573965    m1             13.875
# 22  A. cinerea      Smithsonian 314979    m1             12.525
# 23  A. cinerea      Smithsonian 574897    m1             12.625
# 24  E. lutris       Burke       19112     m1             23.500
# 25  E. lutris       Burke       26459     m1             18.770
# 26  E. lutris       Burke       26773     m1             24.875
# 27  E. lutris       Burke       26801     m1             18.935
# 28  E. lutris       Burke       38671     m1             20.865
# 29  E. lutris       Burke       38672     m1             20.090
# 30  E. lutris       Burke       38673     m1             19.850
# ⋮   ⋮               ⋮           ⋮         ⋮              ⋮
# 866 L. canadensis   Burke       32205     m6              69.700
# 867 L. canadensis   Burke       32210     m6              73.325
# 868 L. canadensis   Burke       32226     m6              68.230
# 869 L. canadensis   Burke       32230     m6              75.255
# 870 L. canadensis   Burke       32237     m6              69.045
# 871 L. canadensis   Burke       32606     m6              78.540
# 872 L. canadensis   Burke       34260     m6              71.665
# 873 L. canadensis   Burke       41398     m6              65.625
# 874 L. canadensis   Burke       41399     m6              68.560
# 875 L. canadensis   Burke       61294     m6              68.010
# 876 L. canadensis   TAMU        2142      m6              68.905
# 877 L. canadensis   TAMU        4212      m6              63.615
# 878 L. canadensis   Burke       20173     m6              68.780
# 879 P. brasiliensis AMNH        30191     m6              96.890
# 880 P. brasiliensis AMNH        777354    m6             107.095
# 881 P. brasiliensis AMNH        937320    m6             110.520
# 882 P. brasiliensis AMNH        30190     m6             100.875
# 883 P. brasiliensis AMNH        74431     m6             101.420
# 884 P. brasiliensis AMNH        98594     m6              99.455
# 885 P. brasiliensis AMNH        78510     m6              90.975
# 886 P. brasiliensis AMNH        92834     m6             108.545
# 887 P. brasiliensis AMNH        98593     m6              78.235
# 888 P. brasiliensis AMNH        74430     m6             100.660
# 889 P. brasiliensis AMNH        91771     m6             105.665
# 890 P. brasiliensis AMNH        98592     m6              77.800
# 891 P. brasiliensis AMNH        71858     m6             100.250
# 892 P. brasiliensis AMNH        78513     m6              95.580
# 893 P. brasiliensis AMNH        91712     m6              97.750
# 894 P. brasiliensis AMNH        71859     m6              88.385
# 895 P. brasiliensis AMNH        73587     m6             106.335
#     species.new
# 1   A. cinerea
# 2   A. cinerea
# 3   A. cinerea
# 4   A. cinerea
# 5   A. cinerea
# 6   A. cinerea
# 7   A. cinerea
# 8   A. cinerea
# 9   A. cinerea
# 10  A. cinerea
# 11  A. cinerea
# 12  A. cinerea
# 13  A. cinerea
# 14  A. cinerea
# 15  A. cinerea
# 16  A. cinerea
# 17  A. cinerea
# 18  A. cinerea
# 19  A. cinerea
# 20  A. cinerea
# 21  A. cinerea
# 22  A. cinerea
# 23  A. cinerea
# 24  E. lutris
# 25  E. lutris
# 26  E. lutris
# 27  E. lutris
# 28  E. lutris
# 29  E. lutris
# 30  E. lutris
# ⋮   ⋮
# 866 L. canadensis
# 867 L. canadensis
# 868 L. canadensis
# 869 L. canadensis
# 870 L. canadensis
# 871 L. canadensis
# 872 L. canadensis
# 873 L. canadensis
# 874 L. canadensis
# 875 L. canadensis
# 876 L. canadensis
# 877 L. canadensis
# 878 L. canadensis
# 879 P. brasiliensis
# 880 P. brasiliensis
# 881 P. brasiliensis
# 882 P. brasiliensis
# 883 P. brasiliensis
# 884 P. brasiliensis
# 885 P. brasiliensis
# 886 P. brasiliensis
# 887 P. brasiliensis
# 888 P. brasiliensis
# 889 P. brasiliensis
# 890 P. brasiliensis
# 891 P. brasiliensis
# 892 P. brasiliensis
# 893 P. brasiliensis
# 894 P. brasiliensis
# 895 P. brasiliensis

# %%
options(repr.plot.res=300, repr.plot.height=7, repr.plot.width=10)
p=ggplot(otter.data, aes(x=value, y=species))
p=p+geom_point(position=position_jitter(h=.15, w=0), alpha=.5)
p=p+facet_wrap(~characteristic, scales="free_x") #or "free_y" for just y
p=p+theme(legend.text=element_text(face='italic')
            , axis.text.x=element_text(color='red'), legend.position='bottom'
         )

p=p+ggtitle('Scatterplot of Value facetted by Characteristic')

p
# Out:
# plot without title
